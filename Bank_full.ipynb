# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv('/content/bank-additional-full-1 (2).csv',sep=';' )

# %%
df
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...       1.0  999.0       0.0
# 1      telephone   may         mon  ...       1.0  999.0       0.0
# 2      telephone   may         mon  ...       1.0  999.0       0.0
# 3      telephone   may         mon  ...       1.0  999.0       0.0
# 4      telephone   may         mon  ...       1.0  999.0       0.0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41194   cellular   nov         fri  ...       3.0  999.0       1.0
# 41195   cellular   nov         fri  ...       3.0  999.0       1.0
# 41196   cellular   nov         fri  ...       3.0  999.0       1.0
# 41197        NaN   NaN         NaN  ...       NaN    NaN       NaN
# 41198   cellular   nov         fri  ...       3.0  999.0       1.0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41194      failure         -1.1          94.767          -50.8      1.028
# 41195      failure         -1.1          94.767          -50.8      1.028
# 41196      failure         -1.1          94.767          -50.8      1.028
# 41197          NaN          NaN             NaN            NaN        NaN
# 41198      failure         -1.1             NaN          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41194       4963.6   no
# 41195       4963.6   no
# 41196       4963.6   no
# 41197          NaN  NaN
# 41198       4963.6   no
#
# [41199 rows x 21 columns]

# %%
df.shape
# Out:
# (41199, 21)

# %%
df['y'].value_counts()
# Out:
# y
# no     36556
# yes     4640
# Name: count, dtype: int64

# %%
df['y'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41190 entries, 0 to 41194
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41190 non-null  float64
#  1   job             41190 non-null  object
#  2   marital         41190 non-null  object
#  3   education       41190 non-null  object
#  4   default         41190 non-null  object
#  5   housing         41190 non-null  object
#  6   loan            41190 non-null  object
#  7   contact         41190 non-null  object
#  8   month           41190 non-null  object
#  9   day_of_week     41190 non-null  object
#  10  duration        41190 non-null  float64
#  11  campaign        41190 non-null  float64
#  12  pdays           41190 non-null  float64
#  13  previous        41190 non-null  float64
#  14  poutcome        41190 non-null  object
#  15  emp.var.rate    41190 non-null  float64
#  16  cons.price.idx  41190 non-null  float64
#  17  cons.conf.idx   41190 non-null  float64
#  18  euribor3m       41190 non-null  float64
#  19  nr.employed     41190 non-null  float64
#  20  y               41190 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41190.000000  41190.000000  41190.000000  41190.000000  41190.000000
# mean      40.026196    258.284074      2.567613    962.477227      0.173003
# std       10.425734    259.272989      2.769948    186.906543      0.494923
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41190.000000    41190.000000   41190.000000  41190.000000  41190.000000
# mean       0.081828       93.575722     -40.503100      3.621165   5167.026033
# std        1.570943        0.578886       4.628642      1.734499     72.263679
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df=df.drop_duplicates()
df.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
for col in df.columns:
  if((df[col].dtype == "int64") or (df[col].dtype == "float64")):
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
#outlier removal
out_list = ['age','duration','campaign','cons.conf.idx']
for i in out_list:
  Q1 = df[i].quantile(0.25)
  Q3 = df[i].quantile(0.75)
  IQR = Q3 - Q1
  df = df[(df[i]>=Q1-1.5*IQR)&(df[i]<=Q3+1.5*IQR)]

# %%
data1=pd.get_dummies(df)
data1
# Out:
#         age  duration  campaign  pdays  previous  emp.var.rate  \
# 0      56.0     261.0       1.0  999.0       0.0           1.1
# 1      57.0     149.0       1.0  999.0       0.0           1.1
# 2      37.0     226.0       1.0  999.0       0.0           1.1
# 3      40.0     151.0       1.0  999.0       0.0           1.1
# 4      56.0     307.0       1.0  999.0       0.0           1.1
# ...     ...       ...       ...    ...       ...           ...
# 41181  37.0     281.0       1.0  999.0       0.0          -1.1
# 41182  29.0     112.0       1.0    9.0       1.0          -1.1
# 41184  46.0     383.0       1.0  999.0       0.0          -1.1
# 41185  56.0     189.0       2.0  999.0       0.0          -1.1
# 41186  44.0     442.0       1.0  999.0       0.0          -1.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  \
# 0              93.994          -36.4      4.857       5191.0  ...
# 1              93.994          -36.4      4.857       5191.0  ...
# 2              93.994          -36.4      4.857       5191.0  ...
# 3              93.994          -36.4      4.857       5191.0  ...
# 4              93.994          -36.4      4.857       5191.0  ...
# ...               ...            ...        ...          ...  ...
# 41181          94.767          -50.8      1.028       4963.6  ...
# 41182          94.767          -50.8      1.028       4963.6  ...
# 41184          94.767          -50.8      1.028       4963.6  ...
# 41185          94.767          -50.8      1.028       4963.6  ...
# 41186          94.767          -50.8      1.028       4963.6  ...
#
#        day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# 0                False             True            False            False
# 1                False             True            False            False
# 2                False             True            False            False
# 3                False             True            False            False
# 4                False             True            False            False
# ...                ...              ...              ...              ...
# 41181             True            False            False            False
# 41182             True            False            False            False
# 41184             True            False            False            False
# 41185             True            False            False            False
# 41186             True            False            False            False
#
#        day_of_week_wed  poutcome_failure  poutcome_nonexistent  \
# 0                False             False                  True
# 1                False             False                  True
# 2                False             False                  True
# 3                False             False                  True
# 4                False             False                  True
# ...                ...               ...                   ...
# 41181            False             False                  True
# 41182            False             False                 False
# 41184            False             False                  True
# 41185            False             False                  True
# 41186            False             False                  True
#
#        poutcome_success   y_no  y_yes
# 0                 False   True  False
# 1                 False   True  False
# 2                 False   True  False
# 3                 False   True  False
# 4                 False   True  False
# ...                 ...    ...    ...
# 41181             False  False   True
# 41182              True   True  False
# 41184             False   True  False
# 41185             False   True  False
# 41186             False  False   True
#
# [35165 rows x 65 columns]

# %%
#outlier detection
for col in df.columns:
  if((df[col].dtype == "int64") or (df[col].dtype == "float64")):
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()

# %%
X=df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#         age          job  marital            education  default housing loan  \
# 0      56.0    housemaid  married             basic.4y       no      no   no
# 1      57.0     services  married          high.school  unknown      no   no
# 2      37.0     services  married          high.school       no     yes   no
# 3      40.0       admin.  married             basic.6y       no      no   no
# 4      56.0     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 41181  37.0       admin.  married    university.degree       no     yes   no
# 41182  29.0   unemployed   single             basic.4y       no     yes   no
# 41184  46.0  blue-collar  married  professional.course       no      no   no
# 41185  56.0      retired  married    university.degree       no     yes   no
# 41186  44.0   technician  married  professional.course       no      no   no
#
#          contact month day_of_week  duration  campaign  pdays  previous  \
# 0      telephone   may         mon     261.0       1.0  999.0       0.0
# 1      telephone   may         mon     149.0       1.0  999.0       0.0
# 2      telephone   may         mon     226.0       1.0  999.0       0.0
# 3      telephone   may         mon     151.0       1.0  999.0       0.0
# 4      telephone   may         mon     307.0       1.0  999.0       0.0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41181   cellular   nov         fri     281.0       1.0  999.0       0.0
# 41182   cellular   nov         fri     112.0       1.0    9.0       1.0
# 41184   cellular   nov         fri     383.0       1.0  999.0       0.0
# 41185   cellular   nov         fri     189.0       2.0  999.0       0.0
# 41186   cellular   nov         fri     442.0       1.0  999.0       0.0
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994          -36.4      4.857
# 1      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  nonexistent          -1.1          94.767          -50.8      1.028
# 41182      success          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
#
#        nr.employed
# 0           5191.0
# 1           5191.0
# 2           5191.0
# 3           5191.0
# 4           5191.0
# ...            ...
# 41181       4963.6
# 41182       4963.6
# 41184       4963.6
# 41185       4963.6
# 41186       4963.6
#
# [35165 rows x 20 columns]

# %%
y
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41181    yes
# 41182     no
# 41184     no
# 41185     no
# 41186    yes
# Name: y, Length: 35165, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in X.columns:
  if X[i].dtype=='object':
    X[i]=le.fit_transform(X[i])
    print(le.classes_)
# Out:
# ['admin.' 'blue-collar' 'entrepreneur' 'housemaid' 'management' 'retired'
#  'self-employed' 'services' 'student' 'technician' 'unemployed' 'unknown']
# ['divorced' 'married' 'single' 'unknown']
# ['basic.4y' 'basic.6y' 'basic.9y' 'high.school' 'illiterate'
#  'professional.course' 'university.degree' 'unknown']
# ['no' 'unknown' 'yes']
# ['no' 'unknown' 'yes']
# ['no' 'unknown' 'yes']
# ['cellular' 'telephone']
# ['apr' 'aug' 'dec' 'jul' 'jun' 'mar' 'may' 'nov' 'oct' 'sep']
# ['fri' 'mon' 'thu' 'tue' 'wed']
# ['failure' 'nonexistent' 'success']

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
rfe=RFE(model)

# %%
rfe.fit(X, y)
# Out:
# RFE(estimator=LogisticRegression())

# %%
rfe.support_
# Out:
# array([False, False,  True,  True,  True, False,  True,  True, False,
#         True, False,  True, False,  True, False, False, False,  True,
#         True, False])

# %%
selected_indices = [i for i,data in enumerate(rfe.support_) if data==True ]
selected_indices
# Out:
# [2, 3, 4, 6, 7, 9, 11, 13, 17, 18]

# %%
column_names =X.columns

# %%
selected_column_names=[column_names[i] for i in selected_indices]

# %%
selected_column_names
# Out:
# ['marital',
#  'education',
#  'default',
#  'loan',
#  'contact',
#  'day_of_week',
#  'campaign',
#  'previous',
#  'cons.conf.idx',
#  'euribor3m']

# %%
X =X.loc[:,['marital',
 'education',
 'default',
 'loan',
 'contact',
 'day_of_week',
 'campaign',
 'previous',
 'cons.conf.idx',
 'euribor3m']]

# %%
X
# Out:
#        marital  education  default  loan  contact  day_of_week  campaign  \
# 0            1          0        0     0        1            1       1.0
# 1            1          3        1     0        1            1       1.0
# 2            1          3        0     0        1            1       1.0
# 3            1          1        0     0        1            1       1.0
# 4            1          3        0     2        1            1       1.0
# ...        ...        ...      ...   ...      ...          ...       ...
# 41181        1          6        0     0        0            0       1.0
# 41182        2          0        0     0        0            0       1.0
# 41184        1          5        0     0        0            0       1.0
# 41185        1          6        0     0        0            0       2.0
# 41186        1          5        0     0        0            0       1.0
#
#        previous  cons.conf.idx  euribor3m
# 0           0.0          -36.4      4.857
# 1           0.0          -36.4      4.857
# 2           0.0          -36.4      4.857
# 3           0.0          -36.4      4.857
# 4           0.0          -36.4      4.857
# ...         ...            ...        ...
# 41181       0.0          -50.8      1.028
# 41182       1.0          -50.8      1.028
# 41184       0.0          -50.8      1.028
# 41185       0.0          -50.8      1.028
# 41186       0.0          -50.8      1.028
#
# [35165 rows x 10 columns]

# %%
y
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41181    yes
# 41182     no
# 41184     no
# 41185     no
# 41186    yes
# Name: y, Length: 35165, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=99)

# %%
X_train
# Out:
#        marital  education  default  loan  contact  day_of_week  campaign  \
# 32573        2          3        0     0        0            1       1.0
# 5818         2          6        0     0        1            1       2.0
# 7595         0          6        0     0        1            0       4.0
# 31259        1          5        0     0        0            4       1.0
# 33403        2          1        1     0        0            3       3.0
# ...        ...        ...      ...   ...      ...          ...       ...
# 27645        2          6        0     0        0            0       2.0
# 25206        1          6        0     2        0            3       2.0
# 40434        1          6        0     0        0            1       3.0
# 27454        1          7        1     0        0            0       2.0
# 33888        2          6        0     0        0            4       1.0
#
#        previous  cons.conf.idx  euribor3m
# 32573       0.0          -46.2      1.299
# 5818        0.0          -36.4      4.857
# 7595        0.0          -36.4      4.864
# 31259       0.0          -46.2      1.334
# 33403       0.0          -46.2      1.291
# ...         ...            ...        ...
# 27645       0.0          -42.0      4.021
# 25206       0.0          -42.0      4.153
# 40434       2.0          -38.3      0.904
# 27454       1.0          -42.0      4.021
# 33888       1.0          -46.2      1.281
#
# [26373 rows x 10 columns]

# %%
y_train
# Out:
# 32573     no
# 5818     yes
# 7595      no
# 31259     no
# 33403     no
#         ...
# 27645     no
# 25206     no
# 40434     no
# 27454     no
# 33888     no
# Name: y, Length: 26373, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_train = lr.predict(X_train)

# %%
print("prediction: ",y_pred)
print("training_prediction: ",y_pred_train)
# Out:
# prediction:  ['no' 'no' 'no' ... 'yes' 'no' 'no']
# training_prediction:  ['no' 'no' 'no' ... 'no' 'no' 'no']

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print("testing accuracy: ",accuracy_score(y_test,y_pred))
print("training accuracy: ",accuracy_score(y_train,y_pred_train))
# Out:
# testing accuracy:  0.9297088262056415
# training accuracy:  0.9214348007431843

# %%
y_test
# Out:
# 30894     no
# 25678     no
# 35391     no
# 15074     no
# 15504     no
#         ...
# 2544      no
# 7922      no
# 39295    yes
# 26887     no
# 9730      no
# Name: y, Length: 8792, dtype: object

# %%
X_test
# Out:
#        marital  education  default  loan  contact  day_of_week  campaign  \
# 30894        1          2        0     0        0            3       3.0
# 25678        1          3        0     0        1            4       1.0
# 35391        1          6        0     2        0            0       2.0
# 15074        2          2        0     0        0            2       1.0
# 15504        1          5        0     0        0            0       5.0
# ...        ...        ...      ...   ...      ...          ...       ...
# 2544         1          3        0     2        1            3       2.0
# 7922         1          6        0     0        1            1       4.0
# 39295        1          6        0     0        0            3       1.0
# 26887        2          6        0     0        0            2       2.0
# 9730         1          2        0     0        1            1       2.0
#
#        previous  cons.conf.idx  euribor3m
# 30894       1.0          -46.2      1.344
# 25678       0.0          -42.0      4.120
# 35391       0.0          -46.2      1.250
# 15074       0.0          -42.7      4.958
# 15504       0.0          -42.7      4.957
# ...         ...            ...        ...
# 2544        0.0          -36.4      4.856
# 7922        0.0          -41.8      4.865
# 39295       2.0          -34.8      0.646
# 26887       0.0          -42.0      4.076
# 9730        0.0          -41.8      4.961
#
# [8792 rows x 10 columns]
